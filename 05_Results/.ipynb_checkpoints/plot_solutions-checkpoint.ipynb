# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
import numpy as np
import pandas as pd
import matplotlib 
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from scipy import interpolate

# %%
matplotlib.rc('xtick', labelsize=25) 
matplotlib.rc('ytick', labelsize=25)

font = {'family' : 'sans-serif',
        'weight' : 'bold',
        'size'   : 25}

matplotlib.rc('font', **font)

# %%
path = "../04_Simulation/45deg/L4/BSL/BUMP_Re_250k_Set3L4_45deg_BSL_no_mapping/"
X0_plane = pd.read_csv(path+'FloorSliceX_0.csv')
Z0_plane = pd.read_csv(path+'FloorSliceZ_0.csv')

# %%
X0_plane
# Out:
#      U:0  U:1  U:2             k  nut      omega         p  Points:0  \
# 0      0    0    0  2.220400e-16    0  2629800.0 -0.010066         0
# 1      0    0    0  2.220400e-16    0  2598500.0 -0.010066         0
# 2      0    0    0  5.426200e-16    0  2661100.0 -0.010066         0
# 3      0    0    0  2.047600e-15    0  2661100.0 -0.010066         0
# 4      0    0    0  6.171700e-15    0  2661100.0 -0.010066         0
# ..   ...  ...  ...           ...  ...        ...       ...       ...
# 188    0    0    0  6.560800e-15    0  2661100.0 -0.018136         0
# 189    0    0    0  2.176800e-15    0  2661100.0 -0.018136         0
# 190    0    0    0  5.700200e-16    0  2661100.0 -0.018136         0
# 191    0    0    0  2.220400e-16    0  2629800.0 -0.018136         0
# 192    0    0    0  2.220400e-16    0  2598500.0 -0.018136         0
#
#      Points:1  Points:2
# 0         0.0   -4.9480
# 1         0.0   -4.9480
# 2         0.0   -4.9480
# 3         0.0   -4.9479
# ...

# %%
Z0_plane
# Out:
#      U:0  U:1  U:2             k  nut      omega         p  Points:0  \
# 0      0    0    0  1.887600e-09    0  2661100.0  0.053541  -32.0950
# 1      0    0    0  2.969800e-09    0  2661100.0  0.049180  -31.7600
# 2      0    0    0  3.850100e-09    0  2661100.0  0.044856  -31.3660
# 3      0    0    0  3.416600e-09    0  2661100.0  0.044701  -30.9030
# 4      0    0    0  2.991300e-09    0  2661100.0  0.044102  -30.3640
# ..   ...  ...  ...           ...  ...        ...       ...       ...
# 329    0    0    0  1.334200e-09    0  2662800.0 -0.008589    2.5607
# 330    0    0    0  1.402500e-09    0  2662900.0  0.002132    2.6214
# 331    0    0    0  1.484800e-09    0  2662900.0  0.014110    2.6869
# 332    0    0    0  1.588700e-09    0  2662700.0  0.027176    2.7568
# 333    0    0    0  1.720700e-09    0  2662200.0  0.040889    2.8308
#
#      Points:1  Points:2
# 0    0.000000       0.0
# 1    0.000000       0.0
# 2    0.000000       0.0
# 3    0.000000       0.0
# ...

# %%
plt.figure(figsize=(30,15), frameon=False)
plt.scatter(X0_plane['Points:2'], X0_plane['p'], s=100, c='k', label='BSL')
#plt.xticks(np.arange(0, 10, step=1))
plt.xlabel("$z/H$")
plt.ylabel("$C_p$")
plt.tight_layout()
#plt.legend(['top', 'bottom', 'LES', 'kOmegaSST-GEP-RANS', 'kOmegaSST-URANS-3D-LAV', 'kOmegaSST-URANS-3D-BSL'], loc='upper left')
#plt.savefig('PH_U.pdf')
plt.legend()
plt.grid()
plt.show()
plt.close()

# %%
plt.figure(figsize=(30,15), frameon=False)

plt.scatter(x_plane['Points:2'], x_plane['p'])

#plt.xticks(np.arange(0, 10, step=1))
plt.ylabel("$y/H$ [-]")
plt.xlabel("$U/u_{b} + x/H$ [-]")
plt.tight_layout()
#plt.legend(['top', 'bottom', 'LES', 'kOmegaSST-GEP-RANS', 'kOmegaSST-URANS-3D-LAV', 'kOmegaSST-URANS-3D-BSL'], loc='upper left')
#plt.savefig('PH_U.pdf')
plt.grid()
plt.show()
plt.close()
